# %% [markdown]
# # <font color='red' style='font-size: 30px;'>Projeto: Estudos do Dataset Público da Olist</font>
# <hr style='border: 2px solid red;'>

# %% [markdown]
# ### Fonte: https://www.kaggle.com/datasets/olistbr/brazilian-ecommerce
#
# ### Descrição:
# <p style='font-size: 14px; line-height: 2; margin: 10px 50px; text-align: justify;'>Este é um banco de dados público disponibilizado pela Olist. Contém informações de 100 mil pedidos de 2016 a 2018 feitos em vários marketplaces no Brasil.</p>
#
# <p style='font-size: 14px; line-height: 2; margin: 10px 50px; text-align: justify;'>São dados comerciais reais e foram anonimizados. As referências às empresas e parceiros foram substituídas pelos nomes das grandes casas de Game of Thrones.</p>
#
# ### Observações:
# <p style='font-size: 14px; line-height: 2; margin: 10px 50px; text-align: justify;'>Para cada pedido é atribuído um customer_id exclusivo. Isso significa que o mesmo cliente receberá IDs diferentes para pedidos diferentes. O customer_unique_id representa o cliente.</p>

# %% [markdown]
# ## <font color='green'>Análise Exploratória</font>

# %% [markdown]
# ### Importando as bibliotecas

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

import pandas as pd
import numpy as np

# %% [markdown]
# ### Data Schema
#
# <img width='900px' src='./data/dataset.png'>

# %%
db_clientes = pd.read_csv('./data/olist_customers_dataset.csv', sep=',')
db_status_pedidos = pd.read_csv('./data/olist_order_items_dataset.csv', sep=',')
db_pagamentos = pd.read_csv('./data/olist_order_payments_dataset.csv', sep=',')
db_pedidos = pd.read_csv('./data/olist_orders_dataset.csv', sep=',')
db_produtos = pd.read_csv('./data/olist_products_dataset.csv', sep=',')

# %%
tipos_status = db_pedidos['order_status']
tipos_status.drop_duplicates(inplace = True) #removendo os duplicados

tipos_status = pd.DataFrame(tipos_status) #transmando em df
tipos_status.index = range(tipos_status.shape[0]) #criando index
tipos_status.columns.name = 'status_id' #renomeando o index
tipos_status
# Out:
# status_id order_status
# 0            delivered
# 1             invoiced
# 2              shipped
# 3           processing
# 4          unavailable
# 5             canceled
# 6              created
# 7             approved

# %%
delivered = db_pedidos['order_status'] == 'delivered'
invoiced = db_pedidos['order_status'] == 'invoiced'
shipped = db_pedidos['order_status'] == 'shipped'
processing = db_pedidos['order_status'] == 'processing'
unavailable = db_pedidos['order_status'] == 'unavailable'
canceled = db_pedidos['order_status'] == 'canceled'
created = db_pedidos['order_status'] == 'created'
approved = db_pedidos['order_status'] == 'approved'

qtdd_delivered = db_pedidos[delivered].shape[0]
qtdd_invoiced = db_pedidos[invoiced].shape[0]
qtdd_shipped = db_pedidos[shipped].shape[0]
qtdd_processing = db_pedidos[processing].shape[0]
qtdd_unavailable = db_pedidos[unavailable].shape[0]
qtdd_canceled = db_pedidos[canceled].shape[0]
qtdd_created = db_pedidos[created].shape[0]
qtdd_approved = db_pedidos[approved].shape[0]

print("Nº de pedidos com status 'Entregue' -> {}".format(qtdd_delivered))
print("Nº de pedidos com status 'Faturado'-> {}".format(qtdd_invoiced))
print("Nº de pedidos com status 'Enviado' -> {}".format(qtdd_shipped))
print("Nº de pedidos com status 'Processando' -> {}".format(qtdd_processing))
print("Nº de pedidos com status 'Indisponível' -> {}".format(qtdd_unavailable))
print("Nº de pedidos com status 'Cancelado'-> {}".format(qtdd_canceled))
print("Nº de pedidos com status 'Criado' -> {}".format(qtdd_created))
print("Nº de pedidos com status 'Aprovado' -> {}".format(qtdd_approved))
# Out:
# Nº de pedidos com status 'delivered' -> 96478
# Nº de pedidos com status 'Faturado'-> 314
# Nº de pedidos com status 'Pago' -> 1107
# Nº de pedidos com status 'Processando' -> 301
# Nº de pedidos com status 'Indisponível' -> 609
# Nº de pedidos com status 'Cancelado'-> 625
# Nº de pedidos com status 'Criado' -> 5
# Nº de pedidos com status 'Apovado' -> 2

# %%
#conferindo se não tem pedidos duplicados em db_pedidos
print('A base de dados "db_pedidos" apresenta {} registros e {} pedidos'.format(db_pedidos.shape[0], db_pedidos['order_id'].nunique()))
# Out:
# A base de dados "db_pedidos" apresenta 99441 registros e 99441 pedidos

# %%
index = [str(i) for i in range(1, 98667)]

# %%
db = pd.merge(db_clientes, db_pedidos, on = 'customer_id') #unindo as bases de dados
db = pd.DataFrame(data=db[['order_id', 'order_status', 'order_approved_at', 'customer_unique_id', 'customer_city', 'customer_state']])

db
# Out:
#                                order_id order_status    order_approved_at  \
# 0      00e7ee1b050b8499577073aeb2a297a1    delivered  2017-05-16 15:22:12
# 1      29150127e6685892b6eab3eec79f59c7    delivered  2018-01-12 20:58:32
# 2      b2059ed67ce144a36e2aa97d2c9e9ad2    delivered  2018-05-20 16:19:10
# 3      951670f92359f4fe4a63112aa7306eba    delivered  2018-03-13 17:29:19
# 4      6b7d50bd145f6fc7f33cebabd7e49d0f    delivered  2018-07-29 10:10:09
# ...                                 ...          ...                  ...
# 99436  6760e20addcf0121e9d58f2f1ff14298    delivered  2018-04-07 16:08:45
# 99437  9ec0c8947d973db4f4e8dcf1fbfa8f1b    delivered  2018-04-04 08:35:12
# 99438  fed4434add09a6f332ea398efd656a5c    delivered  2018-04-08 20:30:03
# 99439  e31ec91cea1ecf97797787471f98a8c2    delivered  2017-11-03 21:31:20
# 99440  28db69209a75e59f20ccbb5c36a20b90    delivered  2017-12-19 18:50:39
#
#                      customer_unique_id          customer_city customer_state
# 0      861eff4711a542e4b93843c6dd7febb0                 franca             SP
# 1      290c77bc529b7ac935b93aa66c333dc3  sao bernardo do campo             SP
# 2      060e732b5b29e8181a18229c7b0b2b5e              sao paulo             SP
# 3      259dac757896d24d7702b9acbbff3f3c        mogi das cruzes             SP
# 4      345ecd01c38d18a9036ed96c73b8d066               campinas             SP
# ...                                 ...                    ...            ...
# 99436  1a29b476fee25c95fbafc67c5ac95cf8              sao paulo             SP
# 99437  d52a67c98be1cf6a5c84435bd38d095d        taboao da serra             SP
# 99438  e9f50caf99f032f0bf3c55141f019d99              fortaleza             CE
# 99439  73c2643a0a458b49f58cea58833b192e                 canoas             RS
# 99440  84732c5050c01db9b23e19ba39899398                  cotia             SP
#
# [99441 rows x 6 columns]

# %%
print('A base de dados "db_status_pedidos" apresenta {} registros e {} pedidos'.format(db_status_pedidos.shape[0], db_status_pedidos['order_id'].nunique()))
# Out:
# A base de dados "db_status_pedidos" apresenta 112650 registros e 98666 pedidos

# %%
db2 = pd.merge(db, db_status_pedidos.groupby('order_id').sum(), on = 'order_id')
db2 = pd.DataFrame(data=db2[['order_id', 'order_status', 'price', 'freight_value', 'order_approved_at', 'customer_unique_id', 'customer_city', 'customer_state']])

#criando um número de nota fiscal fictício para ser o index desse novo db
db2.index = index 
db2.columns.name = 'nota_fiscal'

#criando coluna com valor total da compra
db2['valor_total'] = db2['price'] +  db2['freight_value']

db2
# Out:
# nota_fiscal                          order_id order_status   price  \
# 1            00e7ee1b050b8499577073aeb2a297a1    delivered  124.99
# 2            29150127e6685892b6eab3eec79f59c7    delivered  289.00
# 3            b2059ed67ce144a36e2aa97d2c9e9ad2    delivered  139.94
# 4            951670f92359f4fe4a63112aa7306eba    delivered  149.94
# 5            6b7d50bd145f6fc7f33cebabd7e49d0f    delivered  230.00
# ...                                       ...          ...     ...
# 98662        6760e20addcf0121e9d58f2f1ff14298    delivered   74.90
# 98663        9ec0c8947d973db4f4e8dcf1fbfa8f1b    delivered  114.90
# 98664        fed4434add09a6f332ea398efd656a5c    delivered   37.00
# 98665        e31ec91cea1ecf97797787471f98a8c2    delivered  689.00
# 98666        28db69209a75e59f20ccbb5c36a20b90    delivered   13.99
#
# nota_fiscal  freight_value    order_approved_at  \
# 1                    21.88  2017-05-16 15:22:12
# 2                    46.48  2018-01-12 20:58:32
# 3                    17.79  2018-05-20 16:19:10
# 4                    23.36  2018-03-13 17:29:19
# 5                    22.25  2018-07-29 10:10:09
# ...                    ...                  ...
# 98662                13.88  2018-04-07 16:08:45
# 98663                14.16  2018-04-04 08:35:12
# 98664                19.04  2018-04-08 20:30:03
# 98665                22.07  2017-11-03 21:31:20
# 98666                 7.78  2017-12-19 18:50:39
#
# nota_fiscal                customer_unique_id          customer_city  \
# 1            861eff4711a542e4b93843c6dd7febb0                 franca
# 2            290c77bc529b7ac935b93aa66c333dc3  sao bernardo do campo
# 3            060e732b5b29e8181a18229c7b0b2b5e              sao paulo
# 4            259dac757896d24d7702b9acbbff3f3c        mogi das cruzes
# 5            345ecd01c38d18a9036ed96c73b8d066               campinas
# ...                                       ...                    ...
# 98662        1a29b476fee25c95fbafc67c5ac95cf8              sao paulo
# 98663        d52a67c98be1cf6a5c84435bd38d095d        taboao da serra
# 98664        e9f50caf99f032f0bf3c55141f019d99              fortaleza
# 98665        73c2643a0a458b49f58cea58833b192e                 canoas
# 98666        84732c5050c01db9b23e19ba39899398                  cotia
#
# nota_fiscal customer_state  valor_total
# 1                       SP       146.87
# 2                       SP       335.48
# 3                       SP       157.73
# 4                       SP       173.30
# 5                       SP       252.25
# ...                    ...          ...
# 98662                   SP        88.78
# 98663                   SP       129.06
# 98664                   CE        56.04
# 98665                   RS       711.07
# 98666                   SP        21.77
#
# [98666 rows x 9 columns]

# %%
db2.isna().sum() #verificando se tem valores nulos
# Out:
# nota_fiscal
# order_id               0
# order_status           0
# price                  0
# freight_value          0
# order_approved_at     14
# customer_unique_id     0
# customer_city          0
# customer_state         0
# valor_total            0
# dtype: int64

# %%
db2.dropna(subset='order_approved_at', inplace=True) #removendo os valores nulos

# %%
db2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 98652 entries, 1 to 98666
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            98652 non-null  object
#  1   order_status        98652 non-null  object
#  2   price               98652 non-null  float64
#  3   freight_value       98652 non-null  float64
#  4   order_approved_at   98652 non-null  object
#  5   customer_unique_id  98652 non-null  object
#  6   customer_city       98652 non-null  object
#  7   customer_state      98652 non-null  object
#  8   valor_total         98652 non-null  float64
# dtypes: float64(3), object(6)
# memory usage: 7.5+ MB

# %%
db2['order_approved_at'] = pd.to_datetime(db2['order_approved_at']) #modificando o tipo

# %%
db2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 98652 entries, 1 to 98666
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            98652 non-null  object
#  1   order_status        98652 non-null  object
#  2   price               98652 non-null  float64
#  3   freight_value       98652 non-null  float64
#  4   order_approved_at   98652 non-null  datetime64[ns]
#  5   customer_unique_id  98652 non-null  object
#  6   customer_city       98652 non-null  object
#  7   customer_state      98652 non-null  object
#  8   valor_total         98652 non-null  float64
# dtypes: datetime64[ns](1), float64(3), object(5)
# memory usage: 7.5+ MB

# %%
#renomeando as colunas
db2.rename(columns={'order_id': 'id_pedido',
                                      'order_status': 'status_pedido',
                                      'price': 'valor_produtos',
                                      'freight_value': 'valor_frete',
                                      'order_approved_at': 'data_pedido_aprovado',
                                      'customer_unique_id': 'cliente_id',
                                      'customer_city': 'cidade',
                                      'customer_state': 'UF'},
                             inplace = True)
db2
# Out:
# nota_fiscal                         id_pedido status_pedido  valor_produtos  \
# 1            00e7ee1b050b8499577073aeb2a297a1     delivered          124.99
# 2            29150127e6685892b6eab3eec79f59c7     delivered          289.00
# 3            b2059ed67ce144a36e2aa97d2c9e9ad2     delivered          139.94
# 4            951670f92359f4fe4a63112aa7306eba     delivered          149.94
# 5            6b7d50bd145f6fc7f33cebabd7e49d0f     delivered          230.00
# ...                                       ...           ...             ...
# 98662        6760e20addcf0121e9d58f2f1ff14298     delivered           74.90
# 98663        9ec0c8947d973db4f4e8dcf1fbfa8f1b     delivered          114.90
# 98664        fed4434add09a6f332ea398efd656a5c     delivered           37.00
# 98665        e31ec91cea1ecf97797787471f98a8c2     delivered          689.00
# 98666        28db69209a75e59f20ccbb5c36a20b90     delivered           13.99
#
# nota_fiscal  valor_frete data_pedido_aprovado  \
# 1                  21.88  2017-05-16 15:22:12
# 2                  46.48  2018-01-12 20:58:32
# 3                  17.79  2018-05-20 16:19:10
# 4                  23.36  2018-03-13 17:29:19
# 5                  22.25  2018-07-29 10:10:09
# ...                  ...                  ...
# 98662              13.88  2018-04-07 16:08:45
# 98663              14.16  2018-04-04 08:35:12
# 98664              19.04  2018-04-08 20:30:03
# 98665              22.07  2017-11-03 21:31:20
# 98666               7.78  2017-12-19 18:50:39
#
# nota_fiscal                        cliente_id                 cidade  UF  \
# 1            861eff4711a542e4b93843c6dd7febb0                 franca  SP
# 2            290c77bc529b7ac935b93aa66c333dc3  sao bernardo do campo  SP
# 3            060e732b5b29e8181a18229c7b0b2b5e              sao paulo  SP
# 4            259dac757896d24d7702b9acbbff3f3c        mogi das cruzes  SP
# 5            345ecd01c38d18a9036ed96c73b8d066               campinas  SP
# ...                                       ...                    ...  ..
# 98662        1a29b476fee25c95fbafc67c5ac95cf8              sao paulo  SP
# 98663        d52a67c98be1cf6a5c84435bd38d095d        taboao da serra  SP
# 98664        e9f50caf99f032f0bf3c55141f019d99              fortaleza  CE
# 98665        73c2643a0a458b49f58cea58833b192e                 canoas  RS
# 98666        84732c5050c01db9b23e19ba39899398                  cotia  SP
#
# nota_fiscal  valor_total
# 1                 146.87
# 2                 335.48
# 3                 157.73
# 4                 173.30
# 5                 252.25
# ...                  ...
# 98662              88.78
# 98663             129.06
# 98664              56.04
# 98665             711.07
# 98666              21.77
#
# [98652 rows x 9 columns]

# %%
db2['valor_produtos'] = db2['valor_produtos'].round(2)
db2['valor_frete'] = db2['valor_frete'].round(2)
db2['valor_total'] = db2['valor_total'].round(2)

# %%
db2.to_csv('vendas_olist2.csv', sep = ';')

# %% [markdown]
# ### Análises

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

sns.set_palette("Set2")
sns.set_style("darkgrid")

# %% [markdown]
# Fazendo alguns cortes:
# - apenas pedidos com status = delivered, invoiced, shipped, approved
# - apenas vendas no ano de 2017, porque os anos de 2016 e 2018 do dataset não estão com todos os meses

# %%
#criando a coluna de ano e mês-ano
db2['ano']  = db2['data_pedido_aprovado'].dt.strftime('%Y')
db2['mes_ano'] = db2['data_pedido_aprovado'].dt.strftime('%m-%Y')

# %%
colunas = {0: '2016', 1: '2017', 2: '2018'}
linhas = {0: 'delivered',
          1: 'invoiced',
          2: 'shipped',
          3: 'processing',
          4: 'unavailable',
          5: 'canceled',
          6: 'created',
          7: 'approved'}

frequencia_status = pd.crosstab(db2.status_pedido,
                   db2.ano)

frequencia_status.rename(index= linhas, inplace = True)
frequencia_status.rename(columns = colunas, inplace = True)
frequencia_status
# Out:
# ano            2016   2017   2018
# status_pedido
# approved          0      2      0
# canceled         13    204    244
# delivered       267  43357  52840
# invoiced         16    175    121
# processing        2    240     59
# shipped           8    530    568
# unavailable       6      0      0

# %%
#filtrando os status
status = ['delivered', 'invoiced', 'shipped', 'approved']
selecao_status = db2['status_pedido'].isin(status)

vendas = db2[selecao_status]
vendas
# Out:
# nota_fiscal                         id_pedido status_pedido  valor_produtos  \
# 1            00e7ee1b050b8499577073aeb2a297a1     delivered          124.99
# 2            29150127e6685892b6eab3eec79f59c7     delivered          289.00
# 3            b2059ed67ce144a36e2aa97d2c9e9ad2     delivered          139.94
# 4            951670f92359f4fe4a63112aa7306eba     delivered          149.94
# 5            6b7d50bd145f6fc7f33cebabd7e49d0f     delivered          230.00
# ...                                       ...           ...             ...
# 98662        6760e20addcf0121e9d58f2f1ff14298     delivered           74.90
# 98663        9ec0c8947d973db4f4e8dcf1fbfa8f1b     delivered          114.90
# 98664        fed4434add09a6f332ea398efd656a5c     delivered           37.00
# 98665        e31ec91cea1ecf97797787471f98a8c2     delivered          689.00
# 98666        28db69209a75e59f20ccbb5c36a20b90     delivered           13.99
#
# nota_fiscal  valor_frete data_pedido_aprovado  \
# 1                  21.88  2017-05-16 15:22:12
# 2                  46.48  2018-01-12 20:58:32
# 3                  17.79  2018-05-20 16:19:10
# 4                  23.36  2018-03-13 17:29:19
# 5                  22.25  2018-07-29 10:10:09
# ...                  ...                  ...
# 98662              13.88  2018-04-07 16:08:45
# 98663              14.16  2018-04-04 08:35:12
# 98664              19.04  2018-04-08 20:30:03
# 98665              22.07  2017-11-03 21:31:20
# 98666               7.78  2017-12-19 18:50:39
#
# nota_fiscal                        cliente_id                 cidade  UF  \
# 1            861eff4711a542e4b93843c6dd7febb0                 franca  SP
# 2            290c77bc529b7ac935b93aa66c333dc3  sao bernardo do campo  SP
# 3            060e732b5b29e8181a18229c7b0b2b5e              sao paulo  SP
# 4            259dac757896d24d7702b9acbbff3f3c        mogi das cruzes  SP
# 5            345ecd01c38d18a9036ed96c73b8d066               campinas  SP
# ...                                       ...                    ...  ..
# 98662        1a29b476fee25c95fbafc67c5ac95cf8              sao paulo  SP
# 98663        d52a67c98be1cf6a5c84435bd38d095d        taboao da serra  SP
# 98664        e9f50caf99f032f0bf3c55141f019d99              fortaleza  CE
# 98665        73c2643a0a458b49f58cea58833b192e                 canoas  RS
# 98666        84732c5050c01db9b23e19ba39899398                  cotia  SP
#
# nota_fiscal  valor_total   ano  mes_ano
# 1                 146.87  2017  05-2017
# 2                 335.48  2018  01-2018
# 3                 157.73  2018  05-2018
# 4                 173.30  2018  03-2018
# 5                 252.25  2018  07-2018
# ...                  ...   ...      ...
# 98662              88.78  2018  04-2018
# 98663             129.06  2018  04-2018
# 98664              56.04  2018  04-2018
# 98665             711.07  2017  11-2017
# 98666              21.77  2017  12-2017
#
# [97884 rows x 11 columns]

# %%
#filtrando o ano
vendas_2017 = vendas.query("ano == '2017'")
vendas_2017
# Out:
# nota_fiscal                         id_pedido status_pedido  valor_produtos  \
# 1            00e7ee1b050b8499577073aeb2a297a1     delivered          124.99
# 6            5741ea1f91b5fbab2bd2dc653a5b5099     delivered          259.90
# 8            1093c8304c7a003280dd34598194913d     delivered           19.90
# 11           8428e578bb1cf839ae26a6b7615502b9     delivered           25.30
# 13           83d8f70418eefd96f37b483dff430305     delivered           99.00
# ...                                       ...           ...             ...
# 98656        326c29ec5b89834b17aea7d85302fd70     delivered           89.90
# 98659        ec3a75fb0ac595e461765d2d854b1d08     delivered           59.90
# 98661        c9aea907527f5d4f5fb44955c18a79fb     delivered           55.00
# 98665        e31ec91cea1ecf97797787471f98a8c2     delivered          689.00
# 98666        28db69209a75e59f20ccbb5c36a20b90     delivered           13.99
#
# nota_fiscal  valor_frete data_pedido_aprovado  \
# 1                  21.88  2017-05-16 15:22:12
# 6                  22.31  2017-09-14 18:25:11
# 8                  16.11  2017-11-16 19:55:41
# 11                 15.10  2017-11-27 18:01:20
# 13                 18.31  2017-09-09 10:10:17
# ...                  ...                  ...
# 98656              12.13  2017-05-25 02:50:25
# 98659              24.42  2017-03-15 21:04:08
# 98661              20.88  2017-12-18 00:17:27
# 98665              22.07  2017-11-03 21:31:20
# 98666               7.78  2017-12-19 18:50:39
#
# nota_fiscal                        cliente_id            cidade  UF  \
# 1            861eff4711a542e4b93843c6dd7febb0            franca  SP
# 6            4c93744516667ad3b8f1fb645a3116a4    jaragua do sul  SC
# 8            57b2a98a409812fe9618067b6b8ebe4f           timoteo  MG
# 11           2a7745e1ed516b289ed9b29c7d0539a5     montes claros  MG
# 13           918dc87cd72cd9f6ed4bd442ed785235  lencois paulista  SP
# ...                                       ...               ...  ..
# 98656        277490f0d435b602fe4475d4b89e9181             cotia  SP
# 98659        e7f8760e2bbd2f1986bebd99596c088e             belem  PA
# 98661        4b5820135d360a45552b5163835b1d89       divinopolis  MG
# 98665        73c2643a0a458b49f58cea58833b192e            canoas  RS
# 98666        84732c5050c01db9b23e19ba39899398             cotia  SP
#
# nota_fiscal  valor_total   ano  mes_ano
# 1                 146.87  2017  05-2017
# 6                 282.21  2017  09-2017
# 8                  36.01  2017  11-2017
# 11                 40.40  2017  11-2017
# 13                117.31  2017  09-2017
# ...                  ...   ...      ...
# 98656             102.03  2017  05-2017
# 98659              84.32  2017  03-2017
# 98661              75.88  2017  12-2017
# 98665             711.07  2017  11-2017
# 98666              21.77  2017  12-2017
#
# [44064 rows x 11 columns]

# %%
ax = sns.boxplot(data=vendas_2017['valor_total'], orient='h', width=0.2)

ax.figure.set_size_inches(6, 4)
ax.set_title('Valor Total', fontsize=20)
ax.set_ylabel('$', fontsize=16)
# Out:
# Text(0, 0.5, '$')

# %% [markdown]
#  São muitos outliers

# %%
#melhorando a vizualização
ax = sns.boxplot(data=vendas_2017.query('valor_total < 500').valor_total, orient='h', width=0.4)

ax.figure.set_size_inches(6, 4)
ax.set_title('Valor Total da Venda', fontsize=20)
ax.set_ylabel('$', fontsize=16)
# Out:
# Text(0, 0.5, '$')

# %%
vendas_2017.describe().round(2)
# Out:
# nota_fiscal  valor_produtos  valor_frete  valor_total
# count              44064.00     44064.00     44064.00
# mean                 137.25        22.08       159.33
# std                  216.49        19.45       225.22
# min                    2.29         0.00        10.07
# 25%                   45.90        14.10        61.75
# 50%                   84.99        16.60       103.54
# 75%                  149.90        23.70       175.37
# max                13440.00      1002.29     13664.08

# %%
faturamento_anual = vendas_2017['valor_total'].sum()
qtdd_vendas = vendas_2017['id_pedido'].count()
ticket_medio = (faturamento_anual / qtdd_vendas).round(2)

print('O faturamento total no ano de 2017 foi de ${} e tiveram {} vendas, sendo o ticket médio das vendas igual a ${}.'.format(faturamento_anual, qtdd_vendas, ticket_medio))
# Out:
# O faturamento total no ano de 2017 foi de $7020749.47 e tiveram 44064 vendas, sendo o ticket médio das vendas igual a $159.33.

# %%
faturamento_mensal = vendas_2017.groupby('mes_ano').sum()
faturamento_mensal
# Out:
# nota_fiscal  valor_produtos  valor_frete  valor_total
# mes_ano
# 01-2017           112585.45     15768.88    128354.33
# 02-2017           239324.97     37551.81    276876.78
# 03-2017           359775.23     56370.49    416145.72
# 04-2017           345588.00     51064.33    396652.33
# 05-2017           500735.28     78868.17    579603.45
# 06-2017           431542.97     69800.59    501343.56
# 07-2017           485536.00     85166.49    570702.49
# 08-2017           562881.56     92900.51    655782.07
# 09-2017           609012.07     95576.26    704588.33
# 10-2017           660907.45    103461.67    764369.12
# 11-2017           983936.09    164578.51   1148514.60
# 12-2017           755847.80    121968.89    877816.69

# %%
fig = plt.figure(figsize=(15,8))
eixo = fig.add_axes([0, 0, 1, 1])
eixo.plot(faturamento_mensal.index, faturamento_mensal['valor_total'])

eixo.set_title('Faturamento por Mês', fontsize=25)
eixo.set_ylabel('$', fontsize=20)
eixo.set_xlabel('meses', fontsize=20)
eixo.legend(['faturamento'], loc = 'lower right', fontsize=15)
eixo.grid(True)
